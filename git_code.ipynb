# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Github

# %%
# %cd reinforcement-learning-code
# Out:
# /content/drive/My Drive/Github/reinforcement-learning-code

# %%
# !ls

# %%
# !git config --global user.email "baldo.yuri@gmail.com"
# !git config --global user.name "yax441"

# %%
# Initialize a new repository
# !git init reinforcement-learning-code

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m ""

# %%
https://github.com/yax441/reiforcement-learning.git

# %%
# !git remote add origin https://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@github.com/yax441/reiforcement-learning.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master

# %%
# !ls
# Out:
# git_code.ipynb
